# %%
'''
Q1. What is Flask Framework? What are the advantages of Flask Framework?

ans:
Flask is a micro web framework written in Python. It is designed to be lightweight and easy to use,
making it a popular choice for building small to medium-sized web applications. Flask provides a simple
and flexible way to create web applications by providing a variety of features such as URL routing,
templates, and sessions, while also allowing developers to add their own extensions to further
extend the functionality of the framework.

advantages of flask:

Lightweight: Flask is a lightweight framework with a small core and modular design,
allowing developers to only use the features they need, resulting in
faster development and better performance.

Simple and Easy to Use: Flask has a simple and easy-to-use API that is easy for beginners
to learn, making it a great choice for building simple web applications.

Flexibility: Flask provides developers with a high degree of flexibility in terms of choosing 
the tools and libraries they want to use, making it easy to customize and tailor to their specific needs.
'''

# %%
'''Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook.'''

# code:
from flask import Flask

app=Flask(__name__)

@app.route("/")
def method():
    return "hello world"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:acc24098-52a4-4f27-b969-6d9ce7965636.png)

# %%
'''Q3 What is App routing in Flask? Why do we use app routes?

ans:

In Flask, app routing refers to the process of mapping URLs to specific
functions in the application. App routing is done by creating routes,
which are URL patterns that the application should respond to, and
associating those routes with functions that should be executed when the 
route is requested. this makes the funtcions globally accessible through URLs.

App routing is used in flask for various reasons , such as handling user requests and 
responding to the same.
To map specific URLs to specific functions making it easy to organize the code.

App routes are an essential part of building RESTful APIs, which are used to expose 
resources over the web using a simple and standardized interface.

'''

# %%
'''Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporationt
Location: India
Contact Detail: 999-999-9999'''
#code:
from flask import Flask

app=Flask(__name__)

@app.route("/welcome")
def welcome():
    return " Welcome to ABC Corporation"

@app.route("/")
def details():
    return '''Company Name: ABC<br> 
    Corporationt Location: India<br>
    Contact Detail: 999-999-9999<br>'''

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:8ec04c92-8e99-40e0-89c7-fde4c3282de1.png)

# %% [markdown]
# ![image.png](attachment:2efb3185-9969-48f8-ad3a-21837cd1639b.png)

# %%
'''Q5.What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.

ans:

In Flask, the url_for() function is used for URL building. 
This function generates a URL for a specified function name,
which allows us to easily navigate between different pages in
our Flask application.

'''
#code:
from flask import Flask, url_for

app=Flask(__name__)

@app.route("/welcome")
def welcome():
    return " Welcome to ABC Corporation"

@app.route("/")
def details():
    return '''Company Name: ABC<br> 
    Corporationt Location: India<br>
    Contact Detail: 999-999-9999<br>'''

with app.test_request_context():
    print(url_for('welcome'))
    print(url_for('details'))
if __name__=="__main__":
    app.run(host="0.0.0.0")

#output:
[Running] python -u "/config/workspace/test1.py"
/welcome
/
 * Serving Flask app 'test1'
 * Debug mode: off
[31m[1mWARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.[0m
 * Running on all addresses (0.0.0.0)
 * Running on http://127.0.0.1:5000
 * Running on http://172.18.0.10:5000
[33mPress CTRL+C to quit[0m
